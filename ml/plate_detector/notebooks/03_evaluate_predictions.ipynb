# %% [markdown]
# # 03 Evaluate And Predict
#
# Evaluate the published detector and run visual predictions on your own images.

# %%
from pathlib import Path
import os

WORK_DIR = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
os.chdir(WORK_DIR)
print(WORK_DIR)

# %%
MODEL = "../../src/models/license_plate_detector.pt"
DATA = "data/yolo/russian_plate/data.yaml"
IMGSZ = 960
DEVICE = "auto"

# %%
# !python scripts/evaluate_plate_detector.py \
  --model {MODEL} \
  --data {DATA} \
  --imgsz {IMGSZ} \
  --device {DEVICE} \
  --split test

# %%
# Change SOURCE to an image file, image directory, or video.
SOURCE = "../../tests"
CONF = 0.25

# !python scripts/predict_plate_detector.py \
  --model {MODEL} \
  --source {SOURCE} \
  --imgsz {IMGSZ} \
  --conf {CONF} \
  --device {DEVICE}

# %% [markdown]
# Prediction images and YOLO text outputs are saved under `predictions/visual_check`.
