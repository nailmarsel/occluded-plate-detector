# %% [markdown]
# # Train Car Embedder
#
# Train a ResNet embedder from an ImageFolder dataset where each folder is one vehicle identity or plate number.

# %%
from pathlib import Path
import os

WORK_DIR = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
os.chdir(WORK_DIR)
print(WORK_DIR)

# %%
DATA_DIR = "/path/to/imagefolder"
EPOCHS = 30
BATCH = 64
DEVICE = "auto"

# %%
# !python scripts/train_car_embedder.py \
  --data-dir {DATA_DIR} \
  --epochs {EPOCHS} \
  --batch-size {BATCH} \
  --device {DEVICE} \
  --publish

# %%
# !python scripts/evaluate_car_embedder.py --data-dir {DATA_DIR} --device {DEVICE}
