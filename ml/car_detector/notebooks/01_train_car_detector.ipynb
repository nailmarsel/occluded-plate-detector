# %% [markdown]
# # Train Car Detector
#
# Use this notebook to fine-tune a YOLO vehicle detector on a custom YOLO dataset.

# %%
from pathlib import Path
import os

WORK_DIR = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
os.chdir(WORK_DIR)
print(WORK_DIR)

# %%
DATA = "/path/to/data.yaml"
BASE_MODEL = "yolo11n.pt"
EPOCHS = 80
IMGSZ = 960
BATCH = 16
DEVICE = "auto"

# %%
# !python scripts/train_car_detector.py \
  --data {DATA} \
  --base-model {BASE_MODEL} \
  --epochs {EPOCHS} \
  --imgsz {IMGSZ} \
  --batch {BATCH} \
  --device {DEVICE} \
  --publish
